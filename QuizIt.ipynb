# %%
import os
import cv2
import matplotlib.pyplot as plt
import random
import sys
import shutil

# %%
path = './DataFiles'
#path = './DataFiles/SoccorPlayers'
myDict = {}
dest = './DataFiles/Learnt'
myFolders = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
print(myFolders)
dirName = raw_input("select a directory or '.' for All\n")
if(dirName!='.'):
    path=path+'/'+dirName
    #print(path)
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
             myDict[os.path.splitext(os.path.basename(os.path.normpath(os.path.join(root, file))))[0]] = os.path.join(root, file)
             #print(os.path.splitext(os.path.basename(os.path.normpath(os.path.join(root, file))))[0])
             #print(os.path.join(root, file))
# Out:
# ['Actors', 'Incorrect', 'Learning', 'Learnt', 'Singers']
# select a directory or '.' for All
# ACTORS

# %%
myDict.values()
# Out:
# ['./DataFiles/ACTORS/Al Pacino.jpg',
#  './DataFiles/ACTORS/Amber Heard.jpg',
#  './DataFiles/ACTORS/Alexandra Daddario.jpg']

# %%
dest
# Out:
# './DataFiles/Learnt'

# %%
def Guess(url, name, count):
    while(count<2):
        guess = raw_input("Wrong Answer. Guess Again\n-1 for Answer\n")
        if(guess == '-1'):
            print(name)
            return
        elif(guess.lower()==name.lower()):
            return
        elif count == 1:
            print("Answer : ",name)
            return
        else:
            count+=1

ch = []

while(len(myDict)!=len(ch)):
    choice = random.randint(0,len(myDict)-1)
    if(choice not in ch):
        count = 0
        ch.append(choice)
        im = cv2.imread(list(myDict.values())[choice])
        im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)
        plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
        plt.show()
        guess = raw_input("\nGuess? \n-1 -> Show Answer \n'L' -> Move to 'Learnt' \n0 -> Exit\n")
        if(guess == '-1'):
            print(list(myDict.keys())[choice])
        elif(guess == '0'):
            break
        elif(guess.lower()==list(myDict.keys())[choice].lower()):
            shutil.copy(list(myDict.values())[choice],dest)
            continue
        elif(guess == 'L' or guess == 'l'):
            shutil.copy(list(myDict.values())[choice],dest)
            continue
        else:
            Guess(list(myDict.values())[choice], list(myDict.keys())[choice], count)
# Out:
# Guess?
# -1 -> Show Answer
# 'L' -> Move to 'Learnt'
# 0 -> Exit
# L
# Guess?
# -1 -> Show Answer
# 'L' -> Move to 'Learnt'
# 0 -> Exit
# L
# Guess?
# -1 -> Show Answer
# 'L' -> Move to 'Learnt'
# 0 -> Exit
# L

# %%
path = './Collection'
#path = './DataFiles/SoccorPlayers'
myDict = {}
dest = './DataFiles/Learnt'
myFolders = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]
print(myFolders)
dirName = raw_input("select a directory or '.' for All\n")
if(dirName!='.'):
    path=path+'/'+dirName
    #print(path)
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
             myDict[os.path.splitext(os.path.basename(os.path.normpath(os.path.join(root, file))))[0]] = os.path.join(root, file)
             #print(os.path.splitext(os.path.basename(os.path.normpath(os.path.join(root, file))))[0])
             #print(os.path.join(root, file))
# Out:
# ['ClubPictures', 'FIFA Players Female', 'FIFA Players Male', 'MovieActors', 'SoccorPlayers', 'Top500Actors', 'Top500FemaleActors', 'Top500MaleActors']
# select a directory or '.' for All
# Top500Actors

# %%
ch = []
print("N -> Next \nY -> Move to 'Learnt' \n0 -> Exit\n")
while(len(myDict)!=len(ch)):
    choice = random.randint(0,len(myDict)-1)
    if(choice not in ch):
        count = 0
        ch.append(choice)
        print(list(myDict.keys())[choice])
        guess = raw_input()
        if(guess == 'N' or guess == 'n'):
            continue
        elif(guess == '0'):
            break
        elif(guess == 'Y' or guess == 'y'):
            shutil.copy(list(myDict.values())[choice],dest)
            continue
        else:
            continue
# Out:
# N -> Next
# Y -> Move to 'Learnt'
# 0 -> Exit
#
# Katheryn Winnick
# n
# Lisa Bonet
# n
# Steve Carell
# y
# Marisa Tomei
# n
# Vin Diesel
# y
# Pedro Pascal
# n
# Cara Delevingne
# y
# Katherine Heigl
# n
# Julie Walters
# y
# Armie Hammer
# n
# Brendan Fraser
# n
# Edward Furlong
# n
# Edward Norton
# n
# Jessica Pimentel
# n
# Natasha Lyonne
# n
# Robert De Niro
# y
# Nicolas Cage
# y
# Zachary Levi
# n
# Cobie Smulders
# n
# Priyanka Chopra
# y
# Renée Zellweger
# n
# Idris Elba
# y
# Denzel Washington
# n
# Meryl Streep
# y
# Hugh Jackman
# y
# Malin Akerman
# n
# Domhnall Gleeson
# n
# Sean Harris
# n
# Shailene Woodley
# n
# Zendaya
# y
# André Holland
# n
# Chris Messina
# n
# Nikki Glaser
# n
# M. Night Shyamalan
# n
# Vicci Martinez
# y
# Lisa Ann Walter
# n
# Genesis Rodriguez
# n
# Quentin Tarantino
# n
# Claire Foy
# n
# Vera Farmiga
# n
# Natalia Reyes
# n
# Mackenzie Phillips
# n
# Jane Levy
# n
# Kate Mara
# n
# Wesley Snipes
# n
# Gabriel Macht
# n
# Sam Worthington
# n
# Suki Waterhouse
# n
# Mary-Louise Parker
# n
# Laura Haddock
# n
# Javier Botet
# n
# Anna Faris
# y
# Zazie Beetz
# n
# Dale Soules
# n
# Anya Taylor-Joy
# n
# Sean Young
# n
# Betty Gilpin
# n
# Uzo Aduba
# n
# Andrea Riseborough
# n
# Lena Headey
# n
# Tom Cruise
# y
# Emily Blunt
# y
# Michelle Pfeiffer
# n
# Hailee Steinfeld
# y
# Alexis Bledel
# n
# Helena Bonham Carter
# n
# Jacob Tremblay
# n
# Elle Fanning
# n
# Alia Shawkat
# n
# Colin Firth
# n
# Leonardo DiCaprio
# y
# Nina Dobrev
# y
# Wes Anderson
# y
# Laura Gómez
# n
# Jamie Lee Curtis
# n
# Katee Sackhoff
# n
# Jackie Cruz
# n
# John Travolta
# n
# Rosario Dawson
# n
# Winona Ryder
# n
# Taron Egerton
# n
# Glen Powell
# y
# Kristen Bell
# y
# Rachel Brosnahan
# n
# Jessica Keenan Wynn
# n
# Scarlett Johansson
# y
# Lacey Chabert
# n
# Emily Bett Rickards
# y
# Laura Linney
# n
# Pablo Schreiber
# n
# Steven Spielberg
# n
# Mark Wahlberg
# y
# Diane Lane
# n
# Haley Joel Osment
# n
# Hugh Skinner
# n
# Dwayne Johnson
# y
# T.J. Miller
# n
# Thandie Newton
# n
# David Harbour
# n
# Gemma Chan
# n
# Martha Higareda
# n
# Emma Heming
# n
# Abigail Spencer
# n
# Sam Elliott
# n
# Annabelle Wallis
# n
# Elizabeth Rodriguez
# n
# Jason Momoa
# n
# Val Kilmer
# n
# Joe Manganiello
# n
# Elisabeth Shue
# n
# Jenna Dewan
# n
# Eliza Scanlen
# n
# Amber Heard
# y
# Elizabeth Berkley
# n
# Kate Beckinsale
# n
# Ashton Kutcher
# y
# Ryan Reynolds
# y
# Samuel L. Jackson
# y
# Jessica Biel
# n
# Mary Elizabeth Winstead
# n
# Emily Browning
# 0
